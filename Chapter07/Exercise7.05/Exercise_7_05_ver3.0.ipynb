# %% [markdown]
# ### Exercise 7.05 : Building DCGAN for MNIST

# %%
# Import the required library functions
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import pyplot
import tensorflow as tf
from tensorflow.keras.layers import Input
from tensorflow.keras.initializers import RandomNormal
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Reshape, Dense, Dropout, Flatten,Activation
from tensorflow.keras.layers import LeakyReLU,BatchNormalization
from tensorflow.keras.layers import Conv2D, UpSampling2D,Conv2DTranspose
from tensorflow.keras.datasets import mnist
from tensorflow.keras.optimizers import Adam

# %%
# Function to generate real data samples
def realData(batch):
    # Get the MNIST data 
    (X_train, _), (_, _) = mnist.load_data()
    # Reshaping the input data to include channel
    X = X_train[:,:,:,np.newaxis]
    # normalising the data
    X = (X.astype('float32') - 127.5)/127.5
    # Generating a batch of data
    imageBatch = X[np.random.randint(0, X.shape[0], size=batch)]
    return imageBatch

# %%
# Generating a batch of  images
mnistData = realData(25)

# %%
 # Plotting the images

for j in range(5*5):
    pyplot.subplot(5,5,j+1)
    # turn off axis 
    pyplot.axis('off') 
    pyplot.imshow(mnistData[j,:,:,0],cmap='gray_r')

# %%
# Function to generate inputs for generator function
def fakeInputs(batch,infeats):
    # Generate random noise data with shape (batch,input features)
    x_fake = np.random.uniform(-1,1,size=[batch,infeats])
    return x_fake

# %%
# Function for the generator model
def genModel(infeats):
    # Defining the Generator model
    Genmodel = Sequential()
    Genmodel.add(Dense(512,input_dim=infeats))
    Genmodel.add(Activation('relu'))
    Genmodel.add(BatchNormalization())
    # second layer of FC => RElu => BN layers
    Genmodel.add(Dense(7*7*64))
    Genmodel.add(Activation('relu'))
    Genmodel.add(BatchNormalization())
    # Upsample to 14 x 14
    Genmodel.add(Reshape((7,7,64)))
    Genmodel.add(Conv2DTranspose(32,kernel_size=(5,5),strides=(2,2),padding='same'))
    Genmodel.add(Activation('relu'))
    Genmodel.add(BatchNormalization(axis = -1))
    # Updample to 28 x 28
    Genmodel.add(Conv2DTranspose(1,kernel_size=(5,5),strides=(2,2),padding='same'))
    Genmodel.add(Activation('tanh'))    
    return Genmodel

# %%
# Function to create fake samples using the generator model
def fakedataGenerator(Genmodel,batch,infeats):
    # first generate the inputs to the model
    genInputs = fakeInputs(batch,infeats)
    # use these inputs inside the generator model to generate fake distribution
    X_fake = Genmodel.predict(genInputs)   
    
    return X_fake

# %%
# Define the arguments like batch size and input feature
batch = 128
infeats = 100
Genmodel = genModel(infeats)
Genmodel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               51712
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# batch_normalization_v2 (Batc (None, 512)               2048
# _________________________________________________________________
# dense_1 (Dense)              (None, 3136)              1608768
# _________________________________________________________________
# activation_1 (Activation)    (None, 3136)              0
# _________________________________________________________________
# batch_normalization_v2_1 (Ba (None, 3136)              12544
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 14, 14, 32)        51232
# _________________________________________________________________
# activation_2 (Activation)    (None, 14, 14, 32)        0
# _________________________________________________________________
# batch_normalization_v2_2 (Ba (None, 14, 14, 32)        128
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 28, 28, 1)         801
# _________________________________________________________________
# activation_3 (Activation)    (None, 28, 28, 1)         0
# =================================================================
# Total params: 1,727,233
# Trainable params: 1,719,873
# Non-trainable params: 7,360
# _________________________________________________________________

# %%
# Generating a fake sample and printing the shape
fake = fakedataGenerator(Genmodel,batch,infeats)
fake.shape
# Out:
# (128, 28, 28, 1)

# %%
# Plotting the fake sample

plt.imshow(fake[1, :, :, 0], cmap='gray_r')
 
plt.xlabel('Fake Sample Image')
# Out:
# Text(0.5, 0, 'Fake Sample Image')

# %%
# Descriminator model as a function
def discModel():
    Discmodel = Sequential()
    Discmodel.add(Conv2D(32,kernel_size=(5,5),strides=(2,2),padding='same',input_shape=(28,28,1)))    
    Discmodel.add(LeakyReLU(0.2))
    # second layer of convolutions
    Discmodel.add(Conv2D(64, kernel_size=(5,5), strides=(2, 2), padding='same'))   
    Discmodel.add(LeakyReLU(0.2))
    # Fully connected layers
    Discmodel.add(Flatten())
    Discmodel.add(Dense(512))
    Discmodel.add(LeakyReLU(0.2))
    Discmodel.add(Dense(1, activation='sigmoid'))
    Discmodel.compile(loss='binary_crossentropy', optimizer=Adam(lr=0.0002, beta_1=0.5),metrics=['accuracy'])   
    return Discmodel

# %%
# Print the summary of the discriminator model
Discmodel = discModel()
Discmodel.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 14, 14, 32)        832
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 7, 7, 64)          51264
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               1606144
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 1,658,753
# Trainable params: 1,658,753
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Next we develop the GAN model

# %%
# Define the combined generator and discriminator model, for updating the generator
def ganModel(Genmodel,Discmodel):
    # First define that discriminator model cannot be trained
    Discmodel.trainable = False
    Ganmodel = Sequential()
    # First adding the generator model
    Ganmodel.add(Genmodel)
    # Next adding the discriminator model without training the parameters
    Ganmodel.add(Discmodel)
    # Compile the model for loss to optimise the Generator model
    Ganmodel.compile(loss='binary_crossentropy',optimizer = Adam(lr=0.0002, beta_1=0.5))    
    return Ganmodel

# %%
# Initialise the gan model
gan_model = ganModel(Genmodel,Discmodel)
# Print summary of the GAN model
gan_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 28, 28, 1)         1727233
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 1658753
# =================================================================
# Total params: 3,385,986
# Trainable params: 1,719,873
# Non-trainable params: 1,666,113
# _________________________________________________________________

# %%
# Defining the number of epochs
nEpochs = 5000

# %%
# Train the GAN network
for i in range(nEpochs):
    # Generate samples equal to the bath size from the real distribution
    x_real = realData(batch)
    # Generate fake samples using the fake data generator function
    x_fake = fakedataGenerator(Genmodel,batch,infeats)
    # Concatenating the real and fake data 
    X = np.concatenate([x_real,x_fake])
    # Creating the dependent variable and initializing them as '0'
    Y = np.zeros(batch * 2)
    # making the first set equivalent to batch with labels 1
    Y[:batch] = 1
    # train the  discriminator on the real samples
    discLoss = Discmodel.train_on_batch(X, Y)
    # Generate new fake inputs for training the GAN network
    x_gan = fakeInputs(batch*2,infeats)
    # Create labels of the fake examples as 1 to fool the discriminator
    y_gan = np.ones((batch*2, 1))
    # Update the generator model through the discriminator model
    gan_model.train_on_batch(x_gan, y_gan)
    # Print the accuracy measures on the real and fake data for every 10 epochs
    if (i) % 50 == 0:
        # Printing the descriminator loss and accuracy
        x_real_test = realData(10)
        x_fake_test = fakedataGenerator(Genmodel,10,infeats)
        # Concatenating the real and fake data 
        X_test = np.concatenate([x_real_test,x_fake_test])
        # Creating the dependent variable and initializing them as '0'
        Y = np.zeros(20 * 2)
        Y[:10] = 1
        # Predicting probabilities
        preds = Discmodel.predict_proba(X_test)
        print('Discriminator probability:{D}'.format(D=np.mean(preds)))
        # Generate fake samples using the fake data generator function
        x_fake = fakedataGenerator(Genmodel,batch,infeats)
        # Saving the plots
        for j in range(5*5):
            pyplot.subplot(5,5,j+1)
            # turn off axis 
            pyplot.axis('off')
            pyplot.imshow(x_fake[j,:,:,0],cmap='gray_r')                       
        filename = 'handwritten/GAN_MNIST_Training_Plot%03d.png' % (i)
        pyplot.savefig(filename)
        pyplot.close()
# Out:
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# Discriminator probability:0.6213402152061462
# Discriminator probability:0.7360671758651733
# Discriminator probability:0.6130768656730652
# Discriminator probability:0.5046337842941284
# Discriminator probability:0.5005484223365784
# Discriminator probability:0.50015789270401
# Discriminator probability:0.5000558495521545
# Discriminator probability:0.5000174641609192
# Discriminator probability:0.5000079274177551
# Discriminator probability:0.4999823570251465
# Discriminator probability:0.5000027418136597
# Discriminator probability:0.5000032186508179
# Discriminator probability:0.5000043511390686
# Discriminator probability:0.5000077486038208
# Discriminator probability:0.50001060962677
# Discriminator probability:0.5000385046005249
# Discriminator probability:0.5000142455101013
# Discriminator probability:0.5000492334365845
# Discriminator probability:0.5000683069229126
# Discriminator probability:0.5001295208930969
# Discriminator probability:0.5001870393753052
# Discriminator probability:0.500130832195282
# Discriminator probability:0.5009638667106628
# Discriminator probability:0.5003088116645813
# Discriminator probability:0.5001493096351624
# Discriminator probability:0.5011037588119507
# Discriminator probability:0.5027996897697449
# Discriminator probability:0.5062416195869446
# Discriminator probability:0.9988653063774109
# Discriminator probability:0.5316479802131653
# Discriminator probability:0.537228524684906
# Discriminator probability:0.5458375811576843
# Discriminator probability:0.5272555351257324
# Discriminator probability:0.344757616519928
# Discriminator probability:0.49521365761756897
# Discriminator probability:0.4603431224822998
# Discriminator probability:0.5420417189598083
# Discriminator probability:0.43123894929885864
# Discriminator probability:0.3949892520904541
# Discriminator probability:0.5490063428878784
# Discriminator probability:0.37857556343078613
# Discriminator probability:0.5084751844406128
# Discriminator probability:0.39576226472854614
# Discriminator probability:0.3387141227722168
# Discriminator probability:0.7636926770210266
# Discriminator probability:0.5369698405265808
# Discriminator probability:0.38235634565353394
# Discriminator probability:0.4399162828922272
# Discriminator probability:0.6424551606178284
# Discriminator probability:0.35118338465690613
# Discriminator probability:0.5885065197944641
# Discriminator probability:0.5021446943283081
# Discriminator probability:0.40513548254966736
# Discriminator probability:0.4338921010494232
# Discriminator probability:0.5269685387611389
# Discriminator probability:0.8673129081726074
# Discriminator probability:0.5309993028640747
# Discriminator probability:0.35411232709884644
# Discriminator probability:0.6582547426223755
# Discriminator probability:0.5614713430404663
# Discriminator probability:0.45807480812072754
# Discriminator probability:0.7358125448226929
# Discriminator probability:0.3499308228492737
# Discriminator probability:0.5158140063285828
# Discriminator probability:0.499429315328598
# Discriminator probability:0.4770382344722748
# Discriminator probability:0.41445112228393555
# Discriminator probability:0.4004846513271332
# Discriminator probability:0.2535082697868347
# Discriminator probability:0.5636599063873291
# Discriminator probability:0.31093186140060425
# Discriminator probability:0.36607247591018677
# Discriminator probability:0.5181271433830261
# Discriminator probability:0.42574557662010193
# Discriminator probability:0.380816251039505
# Discriminator probability:0.6670668125152588
# Discriminator probability:0.4823399484157562
# Discriminator probability:0.5708835124969482
# Discriminator probability:0.7270285487174988
# Discriminator probability:0.38011956214904785
# Discriminator probability:0.38623344898223877
# Discriminator probability:0.4022989869117737
# Discriminator probability:0.3804829716682434
# Discriminator probability:0.5739108324050903
# Discriminator probability:0.3566618859767914
# Discriminator probability:0.48248210549354553
# Discriminator probability:0.574987530708313
# Discriminator probability:0.6905745267868042
# Discriminator probability:0.30600792169570923
# Discriminator probability:0.33930546045303345
# Discriminator probability:0.37988775968551636
# Discriminator probability:0.7862714529037476
# Discriminator probability:0.3036342263221741
# Discriminator probability:0.3941431939601898
# Discriminator probability:0.5627273321151733
# Discriminator probability:0.8136324882507324
# Discriminator probability:0.29919710755348206
# Discriminator probability:0.5699641108512878
# Discriminator probability:0.5602294206619263
# Discriminator probability:0.5317003726959229
# Discriminator probability:0.235812708735466
# Discriminator probability:0.5279299020767212
# Discriminator probability:0.3368365168571472
# Discriminator probability:0.46170955896377563
# Discriminator probability:0.3729585111141205
# Discriminator probability:0.7771705389022827
# Discriminator probability:0.3589196801185608
# Discriminator probability:0.57435142993927
# Discriminator probability:0.5169988870620728
# Discriminator probability:0.4179239869117737
# Discriminator probability:0.3097575902938843
# Discriminator probability:0.6737737059593201
# Discriminator probability:0.5063844919204712
# Discriminator probability:0.6992183923721313
# Discriminator probability:0.6810368299484253
# Discriminator probability:0.685871422290802
# Discriminator probability:0.5552968382835388
# Discriminator probability:0.5029728412628174
# Discriminator probability:0.5659688711166382
# Discriminator probability:0.341018408536911
# Discriminator probability:0.6577478647232056
# Discriminator probability:0.42237672209739685
# Discriminator probability:0.47426366806030273
# Discriminator probability:0.3000439405441284
# Discriminator probability:0.4531431198120117
# Discriminator probability:0.25763779878616333
# Discriminator probability:0.5681511759757996
# Discriminator probability:0.4741012156009674
# Discriminator probability:0.573025107383728
# Discriminator probability:0.41577357053756714
# Discriminator probability:0.3897697925567627
# Discriminator probability:0.4409276843070984
# Discriminator probability:0.5446851849555969
# Discriminator probability:0.4841562807559967
# Discriminator probability:0.5269235968589783
# Discriminator probability:0.6073068380355835
# Discriminator probability:0.6369288563728333
# Discriminator probability:0.5315953493118286
# Discriminator probability:0.33772581815719604
# Discriminator probability:0.5882488489151001
# Discriminator probability:0.7380720376968384
# Discriminator probability:0.4975392818450928
# Discriminator probability:0.5577731132507324
# Discriminator probability:0.3820260167121887
# Discriminator probability:0.5134787559509277
# Discriminator probability:0.3016504645347595
# Discriminator probability:0.43707937002182007
# Discriminator probability:0.48942193388938904
# Discriminator probability:0.45327362418174744
# Discriminator probability:0.33599162101745605
# Discriminator probability:0.457388311624527
# Discriminator probability:0.4410696029663086
# Discriminator probability:0.43070703744888306
# Discriminator probability:0.4261507987976074
# Discriminator probability:0.7209758758544922
# Discriminator probability:0.4480023980140686
# Discriminator probability:0.6301432847976685
# Discriminator probability:0.6257023811340332
# Discriminator probability:0.4315760135650635
# Discriminator probability:0.5781775712966919
# Discriminator probability:0.47786790132522583
# Discriminator probability:0.39433008432388306
# Discriminator probability:0.7340724468231201
# Discriminator probability:0.500257670879364
# Discriminator probability:0.4560569226741791
# Discriminator probability:0.6336852312088013
# Discriminator probability:0.6511355638504028
# Discriminator probability:0.46490558981895447
# Discriminator probability:0.45727449655532837
# Discriminator probability:0.5859313011169434
# Discriminator probability:0.5755255222320557
# Discriminator probability:0.510059118270874
# Discriminator probability:0.5978240966796875
# Discriminator probability:0.605016827583313
# Discriminator probability:0.4659793972969055
# Discriminator probability:0.7267248630523682
# Discriminator probability:0.5308167338371277
# Discriminator probability:0.47497615218162537
# Discriminator probability:0.3699260950088501
# Discriminator probability:0.44784021377563477
# Discriminator probability:0.4222725033760071
# Discriminator probability:0.5094103813171387
# Discriminator probability:0.5270403623580933
# Discriminator probability:0.362444132566452
# Discriminator probability:0.6208521127700806
# Discriminator probability:0.4169096350669861
# Discriminator probability:0.4392153322696686
# Discriminator probability:0.7387162446975708
# Discriminator probability:0.4654620289802551
# Discriminator probability:0.532578706741333
# Discriminator probability:0.35670992732048035
# Discriminator probability:0.46847015619277954
# Discriminator probability:0.33576303720474243
# Discriminator probability:0.6076365113258362
# Discriminator probability:0.3912585973739624
# Discriminator probability:0.45371803641319275
# Discriminator probability:0.5126466155052185
# Discriminator probability:0.47121620178222656
# Discriminator probability:0.626846432685852
# Discriminator probability:0.5146232843399048
# Discriminator probability:0.27203166484832764
# Discriminator probability:0.4162817895412445
# Discriminator probability:0.5203601121902466
# Discriminator probability:0.5738962888717651
# Discriminator probability:0.39195337891578674
# Discriminator probability:0.39328333735466003
# Discriminator probability:0.47157591581344604
# Discriminator probability:0.4194304049015045
# Discriminator probability:0.6187564134597778
# Discriminator probability:0.5365875959396362
# Discriminator probability:0.577272891998291
# Discriminator probability:0.3917844891548157
# Discriminator probability:0.5231385827064514
# Discriminator probability:0.6051008105278015
# Discriminator probability:0.5475828647613525
# Discriminator probability:0.39269521832466125
# Discriminator probability:0.6042994856834412
# Discriminator probability:0.5276051163673401
# Discriminator probability:0.41161584854125977
# Discriminator probability:0.5901500582695007
# Discriminator probability:0.5201047658920288
# Discriminator probability:0.3848307430744171
# Discriminator probability:0.5316339135169983
# Discriminator probability:0.512420654296875
# Discriminator probability:0.5139145255088806
# Discriminator probability:0.5782833695411682
# Discriminator probability:0.48999062180519104
# Discriminator probability:0.5180937051773071
# Discriminator probability:0.6891561150550842
# Discriminator probability:0.5197486877441406
# Discriminator probability:0.5387247800827026
# Discriminator probability:0.523591935634613
# Discriminator probability:0.5134792923927307
# Discriminator probability:0.5387589931488037
# Discriminator probability:0.5145907998085022
# Discriminator probability:0.3759658634662628
# Discriminator probability:0.5234724283218384
# Discriminator probability:0.4985573887825012
# Discriminator probability:0.4971686005592346
# Discriminator probability:0.5019547343254089
# Discriminator probability:0.5226042866706848
# Discriminator probability:0.579839289188385
# Discriminator probability:0.6211551427841187
# Discriminator probability:0.5727604627609253
# Discriminator probability:0.45692557096481323
# Discriminator probability:0.5232318639755249
# Discriminator probability:0.4094778597354889
# Discriminator probability:0.6098651885986328
# Discriminator probability:0.5445422530174255
# Discriminator probability:0.80804842710495
# Discriminator probability:0.4859829545021057
# Discriminator probability:0.5183659791946411
# Discriminator probability:0.5034303069114685
# Discriminator probability:0.5696557760238647
# Discriminator probability:0.46322888135910034
# Discriminator probability:0.4578862190246582
# Discriminator probability:0.44313693046569824
# Discriminator probability:0.4712291359901428
# Discriminator probability:0.550231397151947
# Discriminator probability:0.44564342498779297
# Discriminator probability:0.4945407807826996
# Discriminator probability:0.6782697439193726
# Discriminator probability:0.4587453007698059
# Discriminator probability:0.5059918165206909
# Discriminator probability:0.360724538564682
# Discriminator probability:0.46741193532943726
# Discriminator probability:0.5067635774612427
# Discriminator probability:0.4529889225959778
# Discriminator probability:0.4958011507987976
# Discriminator probability:0.490311861038208
# Discriminator probability:0.5786808729171753
# Discriminator probability:0.47216248512268066
# Discriminator probability:0.6365261077880859
# Discriminator probability:0.5222398638725281
# Discriminator probability:0.4720657467842102
# Discriminator probability:0.5851835012435913
# Discriminator probability:0.456442654132843
# Discriminator probability:0.5021623373031616
# Discriminator probability:0.5197655558586121
# Discriminator probability:0.505440354347229
# Discriminator probability:0.4441499710083008
# Discriminator probability:0.41322892904281616
# Discriminator probability:0.5609109997749329
# Discriminator probability:0.483267605304718
# Discriminator probability:0.4702610969543457
# Discriminator probability:0.540443480014801
# Discriminator probability:0.5408416390419006
# Discriminator probability:0.5049363970756531
# Discriminator probability:0.6260831356048584
# Discriminator probability:0.43936967849731445
# Discriminator probability:0.46397238969802856
# Discriminator probability:0.4671362340450287
# Discriminator probability:0.5665481090545654
# Discriminator probability:0.497000128030777
# Discriminator probability:0.6023977994918823
# Discriminator probability:0.45537060499191284
# Discriminator probability:0.418853223323822
# Discriminator probability:0.4689062535762787
# Discriminator probability:0.4965778887271881
# Discriminator probability:0.529639720916748
# Discriminator probability:0.44890356063842773
# Discriminator probability:0.49466457962989807
# Discriminator probability:0.5022749900817871
# Discriminator probability:0.470636785030365
# Discriminator probability:0.4781520962715149
# Discriminator probability:0.4836203157901764
# Discriminator probability:0.4115864336490631
# Discriminator probability:0.4771292805671692
# Discriminator probability:0.5571104884147644
# Discriminator probability:0.47925710678100586
# Discriminator probability:0.5018337965011597
# Discriminator probability:0.7118268609046936
# Discriminator probability:0.4577866196632385
# Discriminator probability:0.5575543642044067
# Discriminator probability:0.4904661178588867
# Discriminator probability:0.5796648263931274
# Discriminator probability:0.39484578371047974
# Discriminator probability:0.5137227177619934
# Discriminator probability:0.5156594514846802
# Discriminator probability:0.38843438029289246
# Discriminator probability:0.4803916811943054
# Discriminator probability:0.4733026623725891
# Discriminator probability:0.6354244947433472
# Discriminator probability:0.5392340421676636
# Discriminator probability:0.5024901628494263
# Discriminator probability:0.3650220036506653
# Discriminator probability:0.4644938111305237
# Discriminator probability:0.434246301651001
# Discriminator probability:0.4361751675605774
# Discriminator probability:0.4025425910949707
# Discriminator probability:0.4489888548851013
# Discriminator probability:0.5342712998390198
# Discriminator probability:0.4243408739566803
# Discriminator probability:0.4531063437461853
# Discriminator probability:0.5613936185836792
# Discriminator probability:0.40510064363479614
# Discriminator probability:0.4913368225097656
# Discriminator probability:0.6239851117134094
# Discriminator probability:0.5164904594421387
# Discriminator probability:0.5762571096420288
# Discriminator probability:0.47083210945129395
# Discriminator probability:0.5398324728012085
# Discriminator probability:0.5209171772003174
# Discriminator probability:0.5325703024864197
# Discriminator probability:0.4821946620941162
# Discriminator probability:0.4871012568473816
# Discriminator probability:0.48624056577682495
# Discriminator probability:0.46550220251083374
# Discriminator probability:0.44362688064575195
# Discriminator probability:0.5593495965003967
# Discriminator probability:0.4864165782928467
# Discriminator probability:0.5198165774345398
# Discriminator probability:0.400391161441803
# Discriminator probability:0.47949308156967163
# Discriminator probability:0.440618097782135
# Discriminator probability:0.5782876014709473
# Discriminator probability:0.518825888633728
# Discriminator probability:0.6289631128311157
# Discriminator probability:0.6060250997543335
# Discriminator probability:0.5047815442085266
# Discriminator probability:0.3746035397052765
# Discriminator probability:0.5595040321350098
# Discriminator probability:0.5128711462020874
# Discriminator probability:0.4758690297603607
# Discriminator probability:0.482712984085083
# Discriminator probability:0.5244909524917603
# Discriminator probability:0.4460526406764984
# Discriminator probability:0.5411535501480103
# Discriminator probability:0.4742077887058258
# Discriminator probability:0.4079933762550354
# Discriminator probability:0.39534300565719604
# Discriminator probability:0.5377551317214966
# Discriminator probability:0.5520007610321045
# Discriminator probability:0.3720552325248718
# Discriminator probability:0.5019252896308899
# Discriminator probability:0.4427207410335541
# Discriminator probability:0.5216395854949951
# Discriminator probability:0.5218191146850586
# Discriminator probability:0.5502461791038513
# Discriminator probability:0.41130390763282776
# Discriminator probability:0.4632796347141266
# Discriminator probability:0.49707087874412537
# Discriminator probability:0.4965794086456299
# Discriminator probability:0.4539722502231598
# Discriminator probability:0.45711764693260193
# Discriminator probability:0.547057032585144
# Discriminator probability:0.46341627836227417
# Discriminator probability:0.4994632601737976
# Discriminator probability:0.6043802499771118
# Discriminator probability:0.5322448015213013
# Discriminator probability:0.4984710216522217
# Discriminator probability:0.5640472173690796
# Discriminator probability:0.5059887170791626
# Discriminator probability:0.5096577405929565
# Discriminator probability:0.49661126732826233
# Discriminator probability:0.39464884996414185
# Discriminator probability:0.4633404612541199
# Discriminator probability:0.4682447016239166
# Discriminator probability:0.5891393423080444
# Discriminator probability:0.45595207810401917
# Discriminator probability:0.4370262026786804
# Discriminator probability:0.5756961107254028
# Discriminator probability:0.6015040874481201
# Discriminator probability:0.5366649627685547
# Discriminator probability:0.47207245230674744
# Discriminator probability:0.5028722882270813
# Discriminator probability:0.575116753578186
# Discriminator probability:0.522377610206604
# Discriminator probability:0.5393944978713989
# Discriminator probability:0.46375688910484314
# Discriminator probability:0.5213328003883362
# Discriminator probability:0.4371609687805176
# Discriminator probability:0.6426495313644409
# Discriminator probability:0.4745712876319885
# Discriminator probability:0.5847785472869873
# Discriminator probability:0.5260737538337708
# Discriminator probability:0.4438238739967346
# Discriminator probability:0.4969584047794342
# Discriminator probability:0.4383416771888733
# Discriminator probability:0.4909157156944275
# Discriminator probability:0.5844547748565674
# Discriminator probability:0.5330686569213867
# Discriminator probability:0.529265284538269
# Discriminator probability:0.3844243288040161
# Discriminator probability:0.40964803099632263
# Discriminator probability:0.4619668424129486
# Discriminator probability:0.5628899335861206
# Discriminator probability:0.5618351697921753
# Discriminator probability:0.43343138694763184
# Discriminator probability:0.4519372582435608
# Discriminator probability:0.5218008756637573
# Discriminator probability:0.4786606729030609
# Discriminator probability:0.5266600847244263
# Discriminator probability:0.5041004419326782
# Discriminator probability:0.4943552017211914
# Discriminator probability:0.5493564605712891
# Discriminator probability:0.461967408657074
# Discriminator probability:0.5691249370574951
# Discriminator probability:0.6080837249755859
# Discriminator probability:0.4343356192111969
# Discriminator probability:0.5004154443740845
# Discriminator probability:0.45980900526046753
# Discriminator probability:0.4688469469547272
# Discriminator probability:0.4736822545528412
# Discriminator probability:0.5117974877357483
# Discriminator probability:0.48958516120910645
# Discriminator probability:0.5669678449630737
# Discriminator probability:0.41776448488235474
# Discriminator probability:0.5007017850875854
# Discriminator probability:0.3981780707836151
# Discriminator probability:0.4343470633029938
# Discriminator probability:0.4784042239189148
# Discriminator probability:0.46499648690223694
# Discriminator probability:0.46007028222084045
# Discriminator probability:0.4294090270996094
# Discriminator probability:0.5306466817855835
# Discriminator probability:0.5525447726249695
# Discriminator probability:0.38481560349464417
# Discriminator probability:0.4805060923099518
# Discriminator probability:0.5328645706176758
# Discriminator probability:0.5229806303977966
# Discriminator probability:0.546506941318512
# Discriminator probability:0.5476754903793335
# Discriminator probability:0.4601097106933594
# Discriminator probability:0.47889024019241333
# Discriminator probability:0.5668320059776306
# Discriminator probability:0.48617950081825256
# Discriminator probability:0.4319058060646057
# Discriminator probability:0.5302526354789734
# Discriminator probability:0.4174579977989197
# Discriminator probability:0.5015031099319458
# Discriminator probability:0.4283139705657959
# Discriminator probability:0.4767410159111023
# Discriminator probability:0.5156697034835815
# Discriminator probability:0.5273799896240234
# Discriminator probability:0.476828008890152
# Discriminator probability:0.4258529245853424
# Discriminator probability:0.5438422560691833
# Discriminator probability:0.5294271111488342
# Discriminator probability:0.6150372624397278
# Discriminator probability:0.5596336126327515
# Discriminator probability:0.45348095893859863
# Discriminator probability:0.6147127151489258
# Discriminator probability:0.5154225826263428
# Discriminator probability:0.5887662768363953
# Discriminator probability:0.6038014888763428
# Discriminator probability:0.4678459167480469
# Discriminator probability:0.544338047504425
# Discriminator probability:0.43511319160461426
# Discriminator probability:0.455252081155777
# Discriminator probability:0.5806958079338074
# Discriminator probability:0.4715786874294281
# Discriminator probability:0.47784337401390076
# Discriminator probability:0.6018800735473633
# Discriminator probability:0.4294600486755371
# Discriminator probability:0.45273059606552124
# Discriminator probability:0.5447977185249329
# Discriminator probability:0.480372816324234
# Discriminator probability:0.5738736987113953
# Discriminator probability:0.5312010049819946

# %% [markdown]
# Let us now generate some fake data using the model we trained and visualize the images

# %%
# Images predicted after training
x_fake = fakedataGenerator(Genmodel,25,infeats)
# Visualizing the plots
for j in range(5*5):
    pyplot.subplot(5,5,j+1)
    # turn off axis 
    pyplot.axis('off')
    pyplot.imshow(x_fake[j,:,:,0],cmap='gray_r')
